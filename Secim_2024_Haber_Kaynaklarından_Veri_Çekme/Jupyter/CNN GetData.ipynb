# %%
sehir=["adana",
"adiyaman",
"afyonkarahisar",
"agri",
"amasya",
"ankara",
"antalya",
"artvin",
"aydin",
"balikesir",
"bilecik",
"bingol",
"bitlis",
"bolu",
"burdur",
"bursa",
"canakkale",
"cankiri",
"corum",
"denizli",
"diyarbakir",
"edirne",
"elazig",
"erzincan",
"erzurum",
"eskisehir",
"gaziantep",
"giresun",
"gumushane",
"hakkari",
"hatay",
"isparta",
"mersin",
"istanbul",
"izmir",
"kars",
"kastamonu",
"kayseri",
"kirklareli",
"kirsehir",
"kocaeli",
"konya",
"kutahya",
"malatya",
"manisa",
"kahramanmaras",
"mardin",
"mugla",
"mus",
"nevsehir",
"nigde",
"ordu",
"rize",
"sakarya",
"samsun",
"siirt",
"sinop",
"sivas",
"tekirdag",
"tokat",
"trabzon",
"tunceli",
"sanliurfa",
"usak",
"van",
"yozgat",
"zonguldak",
"aksaray",
"bayburt",
"karaman",
"kirikkale",
"batman",
"sirnak",
"bartin",
"ardahan",
"igdir",
"yalova",
"karabuk",
"kilis",
"osmaniye",
"duzce"
]

# %%
import requests
from pymongo import MongoClient
import json
import time

# MongoDB bağlantısı oluştur
client = MongoClient("mongodb://localhost:27017/")
db = client["secim_verileri"]
collection = db["anlik_veriler-CNN"]

def fetch_and_store_data():
    # Verileri al
    for i in sehir:
        response = requests.get("https://secim.cnnturk.com/api/mayor/31-mart-2024/city/"+str(i))
        election_data = response.json()
    
        # Verileri MongoDB'ye aktar
        collection.insert_one(election_data)
   
    print("Veriler MongoDB'ye aktarıldı.")

# Belirli aralıklarla verileri al ve MongoDB'ye aktar
while True:
    fetch_and_store_data()
# Out:
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# Veriler MongoDB'ye aktarıldı.
# ...

# %%
 response = requests.get("https://secim.cnnturk.com/api/mayor/31-mart-2024/city/"+str("istanbul"))

# %%
response.content
# Out:
# b'{"cityChest":{"totalChest":33273,"totalOpenChestPercent":77.441168515012172031376791990,"openChest":25767,"totalVoter":11314534,"totalVote":6773214,"validVote":6629968,"invalidVote":143246,"totalJoinPercent":59.862951492301848224593253240},"partyMap":[{"chest":{"totalChest":42,"totalOpenChestPercent":50.0,"openChest":21,"totalVoter":13682,"totalVote":5103,"validVote":4995,"invalidVote":108,"totalJoinPercent":37.297178775032889928373044880},"details":[{"candidate":{"no":"0","name":"Ali Ercan Akpolat","partyNo":"21","url":"/chp/istanbul/adalar/ali-ercan-akpolat-belediye-baskani-adayi/"},"previousTotalVote":null,"previousTotalVotePercent":null,"no":21,"name":"CHP","totalVote":2791,"totalVotePercent":55.875875875875875875875875880,"url":"/chp-yerel-secim-sonuclari/"},{"candidate":{"no":"0","name":"U\xc4\x9fur Sina \xc5\x9een","partyNo":"9","url":"/ak-parti/istanbul/adalar/ugur-sina-sen-belediye-baskani-adayi/"},"previousTotalVote":null,"previousTotalVotePercent":null,"no":9,"name":"AK 
# ...
